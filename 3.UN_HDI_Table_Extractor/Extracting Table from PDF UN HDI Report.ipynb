# %%
pip install camelot-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting camelot-py
#   Using cached camelot_py-1.0.9-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: click>=8.0.1 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (8.1.7)
# Collecting chardet>=5.1.0 (from camelot-py)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.26.1 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (1.26.4)
# Requirement already satisfied: openpyxl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (3.1.5)
# Collecting pdfminer-six>=20240706 (from camelot-py)
#   Using cached pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Collecting pypdf<6.0,>=4.0 (from camelot-py)
#   Using cached pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pandas>=2.2.2 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (2.2.2)
# Requirement already satisfied: tabulate>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (0.9.0)
# Collecting opencv-python-headless>=4.7.0.68 (from camelot-py)
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pypdfium2>=4 (from camelot-py)
#   Using cached pypdfium2-5.2.0-py3-none-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: pillow>=10.4.0 in c:\programdata\anaconda3\lib\site-packages (from camelot-py) (10.4.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0.1->camelot-py) (0.4.6)
# Collecting numpy>=1.26.1 (from camelot-py)
#   Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl>=3.1.0->camelot-py) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.2->camelot-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.2->camelot-py) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.2->camelot-py) (2023.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from pdfminer-six>=20240706->camelot-py) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\programdata\anaconda3\lib\site-packages (from pdfminer-six>=20240706->camelot-py) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py) (1.17.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.2->camelot-py) (1.16.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py) (2.21)
# Using cached camelot_py-1.0.9-py3-none-any.whl (66 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl (38.9 MB)
# Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.4 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/12.6 MB 1.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/12.6 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.6/12.6 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.6 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.6 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.6 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.6 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.4/12.6 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/12.6 MB 1.1 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/12.6 MB 1.2 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/12.6 MB 1.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.4/12.6 MB 1.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.6 MB 1.1 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.6 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.2/12.6 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.6 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.6 MB 1.1 MB/s eta 0:00:07
#    --------------- ------------------------ 5.0/12.6 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.2/12.6 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.2/12.6 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.2/12.6 MB 1.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.6 MB 1.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.6 MB 1.0 MB/s eta 0:00:07
#    ------------------ --------------------- 5.8/12.6 MB 1.0 MB/s eta 0:00:07
#    ------------------ --------------------- 5.8/12.6 MB 1.0 MB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.6 MB 994.9 kB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.6 MB 989.4 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/12.6 MB 991.7 kB/s eta 0:00:07
#    --------------------- ------------------ 6.8/12.6 MB 996.1 kB/s eta 0:00:06
#    ---------------------- ----------------- 7.1/12.6 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 1.0 MB/s eta 0:00:06
#    ------------------------ --------------- 7.6/12.6 MB 972.6 kB/s eta 0:00:06
#    ------------------------ --------------- 7.9/12.6 MB 973.0 kB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.6 MB 979.1 kB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.6 MB 979.1 kB/s eta 0:00:05
#    -------------------------- ------------- 8.4/12.6 MB 973.9 kB/s eta 0:00:05
#    --------------------------- ------------ 8.7/12.6 MB 972.6 kB/s eta 0:00:05
#    ---------------------------- ----------- 8.9/12.6 MB 974.7 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.2/12.6 MB 983.4 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.2/12.6 MB 983.4 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.6 MB 980.2 kB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.6 MB 983.7 kB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 983.7 kB/s eta 0:00:03
#    --------------------------------- ------ 10.5/12.6 MB 1.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 10.7/12.6 MB 1.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 12.1/12.6 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 1.1 MB/s eta 0:00:00
# Using cached pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
# Using cached pypdf-5.9.0-py3-none-any.whl (313 kB)
# Using cached pypdfium2-5.2.0-py3-none-win_amd64.whl (3.1 MB)
# Installing collected packages: pypdfium2, pypdf, numpy, chardet, opencv-python-headless, pdfminer-six, camelot-py
# Successfully installed camelot-py-1.0.9 chardet-5.2.0 numpy-2.2.6 opencv-python-headless-4.12.0.88 pdfminer-six-20251230 pypdf-5.9.0 pypdfium2-5.2.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pypdfium2.exe is installed in 'C:\Users\prash\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\prash\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script chardetect.exe is installed in 'C:\Users\prash\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script camelot.exe is installed in 'C:\Users\prash\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.

# %%
import camelot as cm

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 749E-50E7
#
#  Directory of C:\Users\prash\Desktop\Placement\Automation\project3
#
# 04-01-2026  01:01    <DIR>          .
# 03-01-2026  23:51    <DIR>          ..
# 04-01-2026  00:59    <DIR>          .ipynb_checkpoints
# 04-01-2026  01:01            13,190 Extracting Table from PDF UN HDI Report.ipynb
# 04-01-2026  00:57           850,276 india_factsheet_economic_n_hdi.pdf
# 03-01-2026  23:51                 0 main.py
#                3 File(s)        863,466 bytes
#                3 Dir(s)  303,179,804,672 bytes free

# %%
input_pdf=cm.read_pdf("india_factsheet_economic_n_hdi.pdf",flavor='lattice', pages='1,2')
# Out:
# Overwriting cache for 0 71
# Overwriting cache for 0 71
# Overwriting cache for 0 71

# %%
input_pdf
# Out:
# <TableList n=4>

# %%
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(4, 3)>
# <Table shape=(15, 3)>
# <Table shape=(14, 4)>
# <Table shape=(13, 3)>

# %%
input_pdf[2].df
# Out:
#                                0  \
# 0   Human Development Indicators
# 1                             13
# 2                             14
# 3                             15
# 4                             16
# 5
# 6                             17
# 7                             18
# 8
# 9                             19
# 10
# 11                            20
# 12                            21
# 13                            22
#
#                                                     1       2      3
# 0                                                        2000   2011
# 1                 Human Development Index Value (HDI)   0.461  0.547
# 2                               HDI Rank (out of 187)            134
# 3   Inequality Adjusted Human Development Index Value          0.392
# 4                 Loss in HDI due to Inequalities (%)           28.7
# 5                                                        2001   2011
# 6                       Gender Inequality Index (GII)  0.5531  0.617
# 7                               GII Rank (out of 146)            129
# 8                                                        1996   2006
# 9                    Gender Empowerment Measure (GEM)   0.416  0.497
# 10                                                       2001   2011
# 11                                  Literacy Rate (%)    64.8  74.04
# 12                             Male Literacy Rate (%)    75.3  82.14
# 13                           Female Literacy Rate (%)    53.7  65.46

# %%
df=input_pdf[2].df.loc[11:14,1:3]

# %%
df
# Out:
#                            1     2      3
# 11         Literacy Rate (%)  64.8  74.04
# 12    Male Literacy Rate (%)  75.3  82.14
# 13  Female Literacy Rate (%)  53.7  65.46

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                           1     2      3
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.columns=["KPI", "2001", "2011"]

# %%
df
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.loc[:,["2001","2011"]]=df.loc[:,["2001","2011"]].astype(float)

# %%
df
# Out:
#                         KPI  2001   2011
# 0         Literacy Rate (%)  64.8  74.04
# 1    Male Literacy Rate (%)  75.3  82.14
# 2  Female Literacy Rate (%)  53.7  65.46

# %%
df.to_csv("packt_output.csv")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 749E-50E7
#
#  Directory of C:\Users\prash\Desktop\Placement\Automation\project3
#
# 04-01-2026  01:12    <DIR>          .
# 03-01-2026  23:51    <DIR>          ..
# 04-01-2026  00:59    <DIR>          .ipynb_checkpoints
# 04-01-2026  01:11            28,923 Extracting Table from PDF UN HDI Report.ipynb
# 04-01-2026  00:57           850,276 india_factsheet_economic_n_hdi.pdf
# 03-01-2026  23:51                 0 main.py
# 04-01-2026  01:12               124 packt_output.csv
#                4 File(s)        879,323 bytes
#                3 Dir(s)  303,239,081,984 bytes free

# %%
df.to_excel("packt_output_excel.xlsx")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 749E-50E7
#
#  Directory of C:\Users\prash\Desktop\Placement\Automation\project3
#
# 04-01-2026  01:13    <DIR>          .
# 03-01-2026  23:51    <DIR>          ..
# 04-01-2026  00:59    <DIR>          .ipynb_checkpoints
# 04-01-2026  01:13            30,376 Extracting Table from PDF UN HDI Report.ipynb
# 04-01-2026  00:57           850,276 india_factsheet_economic_n_hdi.pdf
# 03-01-2026  23:51                 0 main.py
# 04-01-2026  01:12               124 packt_output.csv
# 04-01-2026  01:13             5,071 packt_output_excel.xlsx
#                5 File(s)        885,847 bytes
#                3 Dir(s)  303,237,775,360 bytes free

# %%
import seaborn as sns

# %%
df_melted=df.melt('KPI',var_name='year', value_name='percentage')

# %%
df_melted
# Out:
#                         KPI  year percentage
# 0         Literacy Rate (%)  2001       64.8
# 1    Male Literacy Rate (%)  2001       75.3
# 2  Female Literacy Rate (%)  2001       53.7
# 3         Literacy Rate (%)  2011      74.04
# 4    Male Literacy Rate (%)  2011      82.14
# 5  Female Literacy Rate (%)  2011      65.46

# %%
sns.barplot(x="KPI", y="percentage", hue="year", data=df_melted)
# Out:
# <Axes: xlabel='KPI', ylabel='percentage'>
